# %%
# from random import randrange

# %matplotlib inline
from pylab import *

import pandas as pd
import random
random.seed(3)

df = pd.read_csv("C:/Users/moied/Desktop/Data Science/Data Files/XRP_USD_2020-02-12_2020-05-11-CoinDesk.csv")
pageSpeeds = range(len(df['Closing Price (USD)'].values))
purchaseAmount = df['Closing Price (USD)'].values

train = []
for i in range(int(len(pageSpeeds)//0.9)):
    train.append(random.randint(0,len(df['Closing Price (USD)'].values)-1))
rando = np.unique(train)
test=[]
for x in range(len(df['Closing Price (USD)'].values)-1):
    if x not in train:
        test.append(x)



scatter(pageSpeeds, purchaseAmount)

# %%
trainX = []
trainY=[]
testY=[]
testX=[]
for i in train:
    trainX.append(i)
    trainY.append(purchaseAmount[i])

for i in test:
    testX.append(i)
    testY.append(purchaseAmount[i])

# trainX = pageSpeeds[:80]
# testX = pageSpeeds[80:]
#
# trainY = purchaseAmount[:80]
# testY = purchaseAmount[80:]

# %%
x = np.array(trainX)
y = np.array(trainY)

p4 = np.poly1d(np.polyfit(x, y,randint(0,32)))

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0,len(pageSpeeds)+5, 100)
axes = plt.axes()
axes.set_xlim([0,len(pageSpeeds)+5])
axes.set_ylim([0, 0.5])
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %%
testx = np.array(testX)
testy = np.array(testY)

xp = np.linspace(0, len(pageSpeeds)+5, 100)
axes = plt.axes()
axes.set_xlim([0,len(pageSpeeds)+5])
axes.set_ylim([0, 0.5])
plt.scatter(testx, testy)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(testy, p4(testx))

print(r2)

r2 = r2_score(np.array(trainY), p4(np.array(trainX)))

print(r2)
# Out:
# 0.9218062334431271
# 0.9575665492917279
